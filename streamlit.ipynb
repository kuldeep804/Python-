# %% [markdown]
# ### Streamlit
# Streamlit is an open-source Python framework that lets data scientists and developers build and share interactive web applications using only Python code, with no need for HTML, CSS, or JavaScript.
